# %%
import numpy as np
import pandas as pd

pd.set_option('max_rows',5)
data = pd.read_csv('new_data.csv')

# %%
data.head()
# Out:
#    Rank                                      Name        Country    Sales  \
# 0     1                                      ICBC          China  19050.0
# 1     2                            JPMorgan Chase  United States  13620.0
# 2     3                        Berkshire Hathaway  United States  24550.0
# 3     4                   China Construction Bank          China  17350.0
# 4     5  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia  22970.0
#
#    Profit    Assets  Market_value
# 0  4580.0  491470.0       24950.0
# 1  4040.0  368930.0       46480.0
# 2  4250.0   87370.0       62440.0
# 3  3930.0  430170.0       21040.0
# 4  4930.0   51030.0      189720.0

# %%
data['Country'].str.lower()
# Out:
# 0               china
# 1       united states
#             ...
# 1998     south africa
# 1999    united states
# Name: Country, Length: 2000, dtype: object

# %%
data['Product_cost'] = data.Sales - data.Profit

# %%
data
# Out:
#       Rank            Name        Country    Sales   Profit    Assets  \
# 0        1            ICBC          China  19050.0  4580.00  491470.0
# 1        2  JPMorgan Chase  United States  13620.0  4040.00  368930.0
# ...    ...             ...            ...      ...      ...       ...
# 1998  1999     Gold Fields   South Africa    390.0    71.81     750.0
# 1999  1999          Paycom  United States     84.1    14.34     260.0
#
#       Market_value  Product_cost
# 0          24950.0      14470.00
# 1          46480.0       9580.00
# ...            ...           ...
# 1998         890.0        318.19
# 1999        2400.0         69.76
#
# [2000 rows x 8 columns]

# %%
data['new_col'] = True
# Out:
#       Rank            Name        Country    Sales   Profit    Assets  \
# 0        1            ICBC          China  19050.0  4580.00  491470.0
# 1        2  JPMorgan Chase  United States  13620.0  4040.00  368930.0
# ...    ...             ...            ...      ...      ...       ...
# 1998  1999     Gold Fields   South Africa    390.0    71.81     750.0
# 1999  1999          Paycom  United States     84.1    14.34     260.0
#
#       Market_value  Product_cost  new_col
# 0          24950.0      14470.00     True
# 1          46480.0       9580.00     True
# ...            ...           ...      ...
# 1998         890.0        318.19     True
# 1999        2400.0         69.76     True
#
# [2000 rows x 9 columns]
