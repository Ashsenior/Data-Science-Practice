# %%
import numpy as np
import pandas as pd
pd.set_option('max_rows',5)
import json

# %%
df = pd.read_csv('india_fortune.csv')
df2 = pd.read_csv('fortune_2000_in_2021.csv')
df3 = df2.loc[df2.Country=='China']

# %%
new_data = '{"a":1,"b":2,"c":3}'
x=json.loads(new_data)

# %%
data_new = df.join(df3,lsuffix='_India',rsuffix='_China')

# %%
data_new
# Out:
#     Unnamed: 0  Rank_India             Name_India Country_India Sales_India  \
# 0           55          55    Reliance Industries         India     $61.2 B
# 1          109         110    State Bank of India         India     $50.6 B
# ..         ...         ...                    ...           ...         ...
# 48        1957        1958  Central Bank of India         India      $3.6 B
# 49        1966        1967      Avenue Supermarts         India      $3.1 B
#
#    Profit_India Assets_India Market Value_India  int_profit  Rank_China  \
# 0        $5.7 B     $166.3 B           $164.9 B         5.7         1.0
# 1        $3.1 B     $638.1 B            $40.8 B         3.1         NaN
# ..          ...          ...                ...         ...         ...
# 48    $-167.1 M      $49.6 B             $1.4 B      -167.1        49.0
# 49     $129.1 M       $1.7 B            $25.4 B       129.1        50.0
#
# ...

# %%
print(x['b'])
# Out:
# 2
