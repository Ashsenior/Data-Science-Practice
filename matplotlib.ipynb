# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd

# %%
plt.plot([1,2,34,5,6,7],[2,34,5,7,8,9])
plt.title("New Data")
plt.xlabel("This is X")
plt.ylabel("This is Y")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data = pd.read_csv('india_fortune.csv')

# %%
plt.scatter(data.Rank,data.int_profit)
